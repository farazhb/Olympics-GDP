# %% [markdown]
# <style>
#
#     h1 {
#       display: block;
#       max-width: 100%;
#       margin-left: auto;
#       margin-right: auto;
#       text-align: center;
#       font-family: "Arial";
#       font-size: 32px;
#       line-height: 60px;
#       font-style: normal;
#     }
#
#     h2 {
#       font-family: "Arial", serif;
#       font-size: 24px;
#     }
#
#     h3 {
#       font-family: "Arial", serif;
#       font-size: 20px;
#     }
#
#     h4 {
#       font-family: "Arial", serif;
#       font-size: 16px;
#       font-style: oblique;
#     }
#
#     div.text_cell_render {
#       padding-left: 5%;
#       padding-right: 5%;
#       width: 90%;
#       font-family: "Tahoma", serif;
#       font-size: 14px;
#     }
#
# </style>

# %% [markdown]
# <!--
# Potential variable values in report include: References as [[2]], Table/Figure numbers as Table 2, formulae with Latex format dollar-sign-enclosed,
# -->
#
# <br>
# <div align="center"><h1>Correlating The Economic and Olympic <br> Performances of Nations</h1></div>
#
# <br><br>
# <h4>Faraz Hossein-Babaei &#8195; 2016-8-20 ~ 2016-10-20</h4>
# <br>
#
# <h2>Introduction</h2>
#
# <p>The modern Olympics Games vegan in Athens in 1896. The Summer Olympic Games have been taking place every 4 years hosted by different countries ever since the 1896 games, with a few exceptions due to international political disputes. The medal trends of different nations display considerable fluctuations and volatilityies throughout the Olympics history. Influential factors on the athletic performance examined in this study include the economy, represented by a metric in terms of the gross domestic product (GDP) and population of each nations and the hosting of the games. Various other parameters were examined, such as the male/female population ratio, GDP growth, and medical investment; though, their effects were relatively insignificant.
#
# <p>This report studies the correlations among the Olympics performaces according to the medal scores of the countries at the events with external factors of considerable impact on the athletic performance. The most influential determining external factor on the Summer Olympics performance was revealed to be the hosting of the games. Hosts experienced a substantial improvement in their games performance starting a few Olympic events prior to hosting peaking at the event. Though, in most cases, the athletism boost was lost immediately following the games. The analysis of the economy-atheltic trends revealed strong correlations in cases of the majority of the top ranknig nations, particularly of the large-economy countries. The findings of this report enable Olympics performance predictions for the future events of different nations with varying confidence.
#
# <br><br>
#
# <h2>Method</h2>
#
# <p>Original Olympics data and transformation: The data for the Summer Olympics beginning with the 1896 Greece games was collected from the open database "Summer Olympic medallists 1896 to 2008" from [[1]](#References). A few rows of this table with the columns irrelevant to this study discarded are produced in Table 1. The original database, given in terms of athletes winning The Olympics medals, had to be converted to a country-based table for this study by counting the rows (One medal was attributed to one athelete each row) grouped by year, country, and event. In order to attribute a single medal to a nation per team sport event, such events were identified beforehand in prior process of counting through groups based on the year, discipine, event, and gender, respectively. The data was then supplemented with 2008 and 2016 events gathered and confirmed each Olympic year personally from NBC and CBC television network and Google online coverages. The resulting data was indexed based on the participating countries' International Olympic Committee (IOC) acronyms. Table 2 is a segment of this data frame.
#
# <p>Medal scoring scheme: To study the international Olympics performance, a scalar metric was defined to represent the medal score of each country per Olympic games event. A reasonable formula to define the metric was determined as $\;4n_{g}+2n_{s}+n_{b}$, where $n_g,\;n_s,\;and\;n_b$ represent the numbers of gold, silver, and bronze medals, respectively. This [4,2,1] scoring scheme is intuitively more logical than [1,1,1] (assigning equal values to different medal types, i.e. the total number of medals as score), [1,0,0], and the scheme prioritizing a single medal type at a time.
#
# <p>Changing borders and reattribution: Throughout the history of the Olympic games, international borders have been transformed, significantly in the case of the eastern Europe region. The medal of obsolete IOC titles, were reattributed to the modern representatives of those countries. Reattributions are listed specifically in the corresponding code cell comments. In some cases this transformation resulted in skewed medal counts for the current nation, e.g. Germany received larger medal counts during the 1970s and 1980s. Summed calculated medal counts over the history of the games were compared with actual values at [[2]](#References). A random selection of 10 countries' different medal type counts were accurate to within 2%.
#
# <p>Medal score distributions during epochs: Box-whisker plots were prepared to show the Olympics score distributions during 5 distinct periods or epochs defined, over which the scores were averaged. The periods are delineated by historically significant milestones, and all, except the last, contain equal numbers of Summer games. The periods are {1896-1912, 1920-1936, 1948-1964, 1968-1984, 1988-2016}.
#
# <p>Economy data: The GDP data of the nations were obtained [[3]](#References). The data originally providing information per annum during the period 1960-2015. The metric used to represent the economic data was $\;\;GDP\;/\;population^{m}\;$. The power, m, determined as 0.2 after trial and error over the reasonable range, [0,1], considering the best potential fit with the Olympics data. The extremes, absolute GDP and GDP per capita were considered, which, respectively, ranked quite differently relative to the Olympics scores and ranked nations with very small populations highest (many city states at the top) causing mismatch between the top-economy and top-athletic nations. The small m value of 0.2 is reasonable for the economic metric to better correlate with the Olympics scores.
#
# <p>Correlation and hosting analyses: In order to correlate the economy data with the Olympics scores, the GDP table was grouped over periods prior to each Summer Olympics games event, over which the metric values were averaged. This split-combine formed the basis for the economy data to be compared with the Olympics scores. Over many years, certain countries' GDP data was unavailable. The data for those countries over such periods were omitted from the analysis or plots. In review, the Olympic and economic data were presented as the absolute scores and the global shares of the scores (score divided by the global total that year) of those nations. In review, the Olympic medal score is evaluated as $\;4n_{g}+2n_{s}+n_{b}$, and the metric used for the economic data is $\;GDP\;/\;pop^{0.2}$. Plots were prepared revealing the correlation among the countries' Olympic and economic trends during the period 1960-2016 for large-economy countries, which were mostly top Olympics ranking nations as well. Fifth-degree polynomials were fit to each trend and plotted with the data to better exhibit the relationship. A polynomial fit is not fundamnetally representative of the nature of the trends displayed, but it reasonably practically follows them in the plotted range and omits irregularities therein, e.g. the boycotting of the Olympics by various countries in the yeas 1976-1984. In addition, the Olympic data was related with the games' hosting information [[4]](#References).
#
# <br><br>
#
# <h2><b>Results</b></h2>
#
# <h3><b>Olympic Medal Score Distribitions</b></h3>
#
# <p>Table 2 shows a segment of the countries' medal counts, and Table 3 shows the top 10 ranking countries with medal scores accumulated over the period 1960-2016, the Summer Olympics champions of the modern era. These 10 nations' medal score trends throughout the history of the summer games 1896-2016 are plotted in Figure 1. The x-axis is linear with time, and its tick labels indicate years during which Summer Olympic games were held. The scores' global shares or ratios, i.e. the country's scores' fractions of the total global score each year were used to account for the varying numbers of participants. Figure 2 shows the medal score shares of the top nations. Figures 3 and 4 show the normalized trends of Figures 1 and 2 with respect to the 2016 values of the respective nations. The plots show the volatile nature of the trends owing to different factors including statistic, economic and political (e.g. boycotting of the games by various nations in 1976, 1980, and 1984). Furthermore, the games had low attendance in the first decades, and many countries were joining the games for the first time.
#
# <p>The number of participating countries in the games grew gradually from 14 to 206 between the years 1896 and 2016 as shown in Figure 5 [[4]](#References). Most of the top-10 nations exhibit stedy scores overall with evident bright periods. The stably dominant nation has been the US, maintaining a large share of the medal score globally throught the Olympics history, even with the increasing number of countries joining in.
#
# <p>Table 4 shows the fractions of no-medal participating nations during the 5 epochs. The box plots of average medal score distribution during the epochs are produced in Figures 6 and 7. The no-medal countries were excluded from the distributions to allow the log-scale y-axis. Including them results in skewed distributions toward 0 with medians at or near 0. The outliers associated with each box-plot are listed in Tables 5 and 6. The plots do show decreasing median from period to period due to the increasing number of participants with the total global score held relatively with little change. The plots also exhibit narrowing distributions. The drop in median is noticeable most where the rise of the participant number has had the largest rate, at least judging based on the the 5 epochs. The box-whisker portions appear symmetric around the median on the log-scale plots, indicating a more log-normal-like distribtion of the data than a symmetric Gaussian distribution. With the zero-scoring nations included, the medians would skew significantly further toward zero.
#
# <br>
#
# <h3><b>Hosting and performances of nations</b></h3>
#
# <p>Hosting the Olympic games was revealed as the most influential factor on the medal scores, considerably affecting the score trends over 8 years prior to the games, starting about when a nation is selected by the IOC as host. Table 7 lists the hosting nations during the Summer Olympics. Figures 8 a-e show the performances of 1896-2016 host nations in 4-country plot groups, revealing the significance of hosting on their performace. To the credit of the IOC, the scores of hosts rise considerably a few summer games prior to hosting and peak at the event. The trend is not sustained in most cases, however, and reverses dropping the score to the background level the following event. South Korea, The Great Britain, and Australia have shown to be exceptions to this pattern and retain part of the boost. The other exceptions to the pattern include the first few decades of the Olympics history and and of The US and Germany. In the case of Germany the performance appears to rise after its 1972 hosting, an artifact due to the reattribution of East and West Germany's medals to the unified Germany to avoid discontinuity of the nation's trend.
#
# <br>
#
# <h3><b>The Economics and Olympics Scores Correlation</b></h3>
#
# <p>The top countries' score global shares shows reduction during the games' over-century history because of the rising number of medal-winning developing nations joining The Olympics. Tables 8 and 9 show top nations ranked based on 2016 economy and Olympic score data. Global shares of economic and Olympic performance data formed the basis for the correlation analysis.
#
# <p>Plots comparing the economic and medal score trends of large-economy nations are shown in Figures 9 a-p. The large-economy-nations exhibit the stronger correlations among the chosen parameters. Figures 10 a-d additionally plot the performances of four nations also high-ranking that exhibit strong correlations. Polynomials of degree 5 fit to the data better exhibit the trends, less sensitive to volatilities and irregularities in the data.
#
# <p>As mentioned, and as evident in these figures, the top ranking nations show overall downward trends, both economically and athletically, owing to the increasing number of participating nations globally, which the top performers' influence. In most cases, the top ranking nations do display strong economic-athletic correlations. USA, Germany, Great Britain, and Canada display a calm background, gradually weakening with rising participation number screening effect. Around hosting of events, the athletic trend is temporarily excited and peaks relative to the economic trend.
#
# <p>China, Italy, Brazil, Korea, Russia, and Mexico show more dynamic correlated trends. China's both metrics begin their rise in the late 1980s. Its Olympics trend is unique in that the nation only began participation in 1984 and has had sharp rise in the performance ever since. Nevertheless, its score dropped relatively slightly atfer the hosting of the Beijing games in 2008. Italy hosted the Summer Olympics in 1960. Beside follwoing that year the trends agree in that they rise until min 1990s after which they reverse slightly. Brazil, one of the BRICS nations, shows rising trends in both cases quite agreeing with regard second time-derivative. While Russia's data is unavailable for years prior to the 1990s, following that time, they correlate well with sub-decade-long fluctuations while the athletic performace shows a gradual decline. Korea's both trends show, following a slowdown until 1968, sharp rise until 2000, after which the rise has slowed. India's athletic data trend based a the few medals won do show agreement with its economic performance.
#
# <p>In th case of a minority of nations, though, the trends show weak correlations, one relatively leading or lagging the other, or no evident connection at all. These include Japan, France, Australia, and Spain, and in the case Netherlands alone the trends appear anticorrelated. In the case of Japan, the economy peaked in 1996, whereas with the Olympics data, after the drop in score following hosting of the Olympics in 1964, the athletic trend has been rising gradually, now sharpening toward its 2020 hosting of the ganes. Jamaica's plot was added out of interest. It exhibits strong athletic performance and rising trend relative to its declining economy share. I believe its sport-focused culture and effective investment in its Olympics performace are causes to the strong medal scores. Notable Jamaican athletes regularly win the gold medals at the events, particularly in track-and-field. Sweden and Colombia also display a strong connection among the economic and Olympic trends.
#
# <br><br>
#
# <h2><b>Conclusion</b></h2>
#
# <p>Olympics data about countries' performances during the history of the games were studied to reveal influential factors affecting their trends during that time. While, exceptions, data discontinuous, and volatile trends make it difficult to reliably study the potential causes of change, two factors were revealed to substantially do so: The economic trend of the nations and the hosting of the Olympic games.
#
# <p>Economiy data were obtained for the years beginning in 1960. Plotting representative metrics of the performances based on the data with curves fit to them revealed in most cases of the top performers correlated trends. The countries also ranked absolutely similarly for the Olympic and economic performances.
#
# <p>Also, patterns of peaks relative to the trend backgrounds coincident with the hosting of the games revealed the significant effect of hosting on the Olympics medal scores. These findings may help one predict the results of the upcoming Olympic games with varying confidence for different nations.
#
# <br><br>
#
# <h2>References</h2>
#
# [[1]] [r1] The Guardian, "Olympic medal winners: Every one since 1896 as open data", published 2012-6-24, collected 2016-8-20
# [r1]: https://www.theguardian.com/sport/datablog/2012/jun/25/olympic-medal-winner-list-data
# [[2]] [r2] Wikipedia, "All-time Olympic Games medal table", published 2012-6-24, collected 2016-8-20
# [r2]: https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table
# [[3]] [r3] World Development Indicators, collected 2016-9-14
# [r3]: http://databank.worldbank.org/data/reports.aspx?source=world-development-indicators
# [[4]] [r4] Wikipedia, "List of participating nations at The Summer Olympic Games"
# [r4]: https://en.wikipedia.org/wiki/List_of_participating_nations_at_the_Summer_Olympic_Games
# [[5]] [r5] Wikipedia, "Mixed teams at The Olympics"
# [r5]: https://en.wikipedia.org/wiki/Mixed_teams_at_the_Olympics
#
# <br>

# %%
""" Faraz Hossein-Babaei   2016/8/24 ~ ...   Correlating economies and Olympics scores of countries """
""" Data Reading Segment: Reads dataframe from Olympics source table and cleans up the table """

import pandas as pd
import numpy as np
import matplotlib as plt
from IPython.display import display
# %matplotlib inline


medals_df = pd.read_csv("..\olympic_summer_medals_1896_2008_athletes.csv")
medals_df.columns = medals_df.iloc[3,:]   # retitle the columns based on a row in file
medals_df.columns.name = ""   # Blanking the index column.
medals_df.drop(medals_df.index[0:4], axis=0, inplace=True)   # remove residual first file rows 0-3
medals_df.reset_index(drop=True, inplace=True)   # reset the index. 4-... --> back to 0-...
medals_df.rename(columns={"Edition":"Year"}, inplace=True)   # column Edition --> .Year

print ("Table 1: The format of the useful subset of source table for this analysis.")
display (medals_df.head(n=4))

new_medal_types = [1 if x == "Gold" else (2 if x == "Silver" else (3 if x == "Bronze" else 0))   for x in medals_df.Medal]
medals_df["Medal"] = new_medal_types
medals_df["Medal"] = medals_df["Medal"].astype(np.int8)
# Drop the columns we won't be using (doesn't affect time cost of running it much)
medals_df.drop(['City','Sport','Athlete','Event_gender'], axis=1, inplace=True)
# Out:
# Table 1: The format of the useful subset of source table for this analysis.
#      City  Year     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens  1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens  1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens  1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens  1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %%
""" Team Events Distinction Segment: For deriving countries' medal wins from the source table of
athletes-based medal attainments """

# Let us get the team sports in "discipline : event" format.
concise = medals_df.copy()
team_events = set()
concise_groupby = concise.groupby(['Year','Discipline','Event','Gender'])
concise_groupby_count = concise_groupby.count()

for idx, row in concise_groupby_count.iterrows():
    if row["Medal"] > 4:
        team_events.add(idx[1] + " : " + idx[2])

# For manual evaluation of what comes considered as presumable team sports
#print (len(team_events))
#for team_event in team_events:
#    print(team_event)

# %%
""" Deriving Country Medal Counts Segment: Finding countries' medal wins from the source table of
athletes-based medal wins. For actual country totals see [2] """

# Make a table for each unique country's medals each year
new_cols = []
for x in medals_df["Year"].unique():
    new_cols += [x + " G", x + " S", x + " B"]
idx = sorted(medals_df["NOC"].unique())
mdl_countries_df = pd.DataFrame(data=0, index=idx , columns=new_cols )
mdl_countries_df.fillna(0, inplace=True)

# Dictionary used to convert medal column to integer type herein
medal_types = {1:"G",2:"S",3:"B"}
# Count the medals, now let us. For team events, country wins one medal per team event
row_iter = medals_df.iterrows()
for idx, row in row_iter:
    team_disc, team_event = row["Discipline"], row["Event"]
    if (team_disc+" : "+team_event in team_events):   # Even if supposed team event actually singles, correct result is calculated
        team_medal_counts_dict = {}   # dict to be filled by keys (countries) and values (arrays of the country's team medals)
        while True:   # incrementing rows, count total team medals
            if row["NOC"] not in team_medal_counts_dict:   # If country isn't in the team event medals dictionary
                team_medal_counts_dict[row["NOC"]] = np.zeros(3, dtype=np.int16)
            team_medal_counts_dict[row["NOC"]][row["Medal"]-1] += 1
            if medals_df.loc[idx+1,"Discipline"] != team_disc or medals_df.loc[idx+1,"Event"] != team_event:
                break
            idx, row = next(row_iter)   # NOTE: Here we're INCREMENTING through rows as well as the base loop hereout
        medal_nums = []   # finding min num medals won by a country in a team event whatever type
        for key, value in team_medal_counts_dict.items():
            for num in value:   # The min gives us a base value to divide other medal nums by to decide ow many medals country won
                medal_nums += [num]
        base_num = min([num for num in medal_nums if num != 0])
        for country in team_medal_counts_dict:   # assign num medals to country
            for medal_type in range(1,4):
                medal_contrib = team_medal_counts_dict[country][medal_type-1] // base_num
                mdl_countries_df.loc[country , row["Year"]+" "+medal_types[medal_type]] += medal_contrib
    else:
        mdl_countries_df.loc[ row["NOC"] , row["Year"]+" "+medal_types[row["Medal"]] ] += 1   # adding medal contribution each row

#print ("Table showing a few rows of the nations' Olympics medal counts up to 2008.")
#display (mdl_countries_df.iloc[50:54,:])

# %%
""" Appending New Data Segment: adding data from 2012,2016 Olympics from my dad recorded in excel files
in the respective anni """

london2012 = pd.read_csv("..\London Olympics medals.tsv", sep='\t')
rio2016 = pd.read_csv("..\Rio Olympics medals.tsv", sep='\t')
ioc_codes_df = pd.read_csv("..\ioc country codes.tsv", sep='\t')
ioc_codes_df["Int Olympic Committee code"] = ioc_codes_df["Int Olympic Committee code"].replace("ROM", "ROU")   # fixing mistake
ioc_codes_df["Country"] = ioc_codes_df["Country"].str.replace("*", "")   # removig some asterisks at ends of country names
ioc_codes_df.set_index("Country", drop=True, inplace=True)
ioc_codes_df.rename(columns={"Int Olympic Committee code":"IOCode"}, inplace=True)   # column of long name --> .IOCode
ioc_codes_df.to_csv("ioc country codes corrected.tsv", sep='\t')

london2012.set_index(london2012["Country"].map(ioc_codes_df["IOCode"]), inplace=True)   # Derive NOC codes from name and set_index
rio2016.set_index(rio2016["Country"].map(ioc_codes_df["IOCode"]), inplace=True)   # Derive NOC codes from name and set as index
london2012.index.name = ""
rio2016.index.name = ""
# Now, add the countries new in the last 2 Olympics to the medals table
londonNew = london2012["Country"][~london2012.index.isin(mdl_countries_df.index)]
rioNew = rio2016["Country"][~rio2016.index.isin(mdl_countries_df.index)]
missing_countries_df = pd.concat([londonNew, rioNew])
miss_ctr = missing_countries_df.groupby(missing_countries_df.index).first()
for noc in miss_ctr.index:
    mdl_countries_df.loc[noc,:] = 0
mdl_countries_df.sort_index(inplace=True)   # reset the index. 4-... --> back to 0-...
mdl_countries_df
# Now add the contributions at the 2012. 2016 Olympics
mdl_countries_df["2012 G"], mdl_countries_df["2012 S"], mdl_countries_df["2012 B"] = \
            london2012["2012 G"], london2012["2012 S"], london2012["2012 B"]
mdl_countries_df["2016 G"], mdl_countries_df["2016 S"], mdl_countries_df["2016 B"] = \
            rio2016["2016 G"], rio2016["2016 S"], rio2016["2016 B"]
mdl_countries_df.fillna(value=0, inplace=True)   # countries not won medals get an N/A, None, null for the 2 Olympics. Fill with 0
mdl_countries_df = mdl_countries_df.astype(np.int)

mdl_countries_df.to_csv("complete_countries_medals.csv")   # We won't use, but save for ref in case
#display(mdl_countries_df.iloc[20:24,:])

# %%
""" Special treatement segment: Caring for anomalies/exceptions (SU is only one with significant
effect, still not on my specific analyses).
ANZ: Australasia (Australia & New Zealand 1908,1912)       given to Australia
BOH: Bohemia (Czech effectively, many Olympics)            given to Czech
BWI: Brit. West Indies 1960 (Jamc., Trin.&Tobago, Brbds.)  given to Jamaica
EUA: United team of Germany                                given to Germany
EUN: United team (almost former soviet: 1992 only)         given to Russia
FRG: West Germany                                          given to Germany
GDR: East Germany                                          given to Germany
IOP: Indpt. Olympic particp. (Yug 1992, cont individuals)  kept independent
RU1: Russian Empire                                        given to Russia
SRB: Serbia & Montenegro (1996-2000)                       given to Serbia
TCH: Czechoslovakia                                        given to Czech
URS: Soviet Union                                          given to Russia
YUG: Yugoslavia                                            given to Serbia
ZZX: Mixed teams [5]                                       omitted
"""

mdl_countries_df_copy = mdl_countries_df

print ("Test: Germany's total medal count before and after reattribution:")
print("GER" + ":  " + str(mdl_countries_df.loc["GER", :].sum()))   # test pre since this cell is to run only once
mdl_countries_df_copy.loc["AUS", :] += mdl_countries_df.loc["ANZ", :]
mdl_countries_df_copy.loc["CZE", :] += mdl_countries_df.loc[["BOH", "TCH"], :].sum()
mdl_countries_df_copy.loc["GER", :] += mdl_countries_df.loc[["EUA", "FRG", "GDR"], :].sum()
mdl_countries_df_copy.loc["JAM", :] += mdl_countries_df.loc["BWI", :]
mdl_countries_df_copy.loc["RUS", :] += mdl_countries_df.loc[["EUN", "RU1", "URS"], :].sum()
mdl_countries_df_copy.loc["SCG", :] += mdl_countries_df.loc[["SRB", "YUG"], :].sum()
print("GER" + ":  " + str(mdl_countries_df.loc["GER", :].sum()))   # test epi since this cell is to run only once

mdl_countries_df_copy.loc[["EUA", "FRG", "GDR"], :].sum().sum()   # test cont'd.. Well this should difference of 2 outputs prior
mdl_countries_df_copy.drop(["ANZ", "BOH", "TCH", "EUA", "FRG", "GDR", "BWI", "EUN", "RU1", "URS", "SRB", "YUG"], axis=0, inplace=True)

# This actually forms the main table we'll use in our analysis, read from the file hereby being saved to:
mdl_countries_df_copy.to_csv("complete_countries_medals_reattributed.csv")   # save to file after reassigning old medals to modern nations
#display(mdl_countries_df_copy.iloc[20:24,:])
# Note: Among 20 random nations evaluated, all were within 2% of correct value (!) based on [2]
# Out:
# Test: Germany's total medal count before and after reattribution:
# GER:  618
# GER:  1350
